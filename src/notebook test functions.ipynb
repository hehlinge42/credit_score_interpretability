# %%
import pandas as pd

# %%
data = pd.read_csv("../data/input.csv", sep=";")
data[data["y_hat"].isna()]
a = data.dropna(axis='index')\
    .drop(columns=['y_hat'])

# %%
data.dropna(axis='index').reset_index(drop=True)
# Out:
#      CreditDuration  CreditAmount  InstallmentRate  Age  NumberOfCredits  \
# 0                12          2096                2   49                1
# 1                24          1282                4   32                1
# 2                12          1804                3   44                1
# 3                60          6836                3   63                2
# 4                18          1913                3   36                1
# ..              ...           ...              ...  ...              ...
# 595              18           976                1   23                1
# 596               9          1449                3   27                2
# 597              30          2181                4   36                2
# 598              60          7418                1   27                1
# 599               6          1595                3   51                1
#
#     CreditHistory EmploymentDuration Housing Purpose Savings  Group  Gender  \
# ...
